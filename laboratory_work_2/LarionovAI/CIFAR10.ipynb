# %%
import torch
import torch.nn as nn
import torchvision
if torch.cuda.is_available: device = "cuda" 
else: device = "cpu"
print(device)
# Out:
# cuda

# %%
trainset = torchvision.datasets.CIFAR10(root='./', train=True, download=True, transform=torchvision.transforms.ToTensor())
testset  = torchvision.datasets.CIFAR10(root='./', train=False, download=True, transform=torchvision.transforms.ToTensor())

# %%
from torch.utils.data import DataLoader


trainloader = torch.utils.data.DataLoader(trainset, batch_size=100, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=100)

# %%
from torch.optim import AdamW
from torch.nn import CrossEntropyLoss

# %%
for x,y in trainloader:
    print(x.shape)
    print(y.shape)
    break
# Out:
# torch.Size([100, 3, 32, 32])
# torch.Size([100])

# %%
class ConvNN(torch.nn.Module):
    
    def __init__(self):
        
        super().__init__()
        self.conv = torch.nn.Conv2d(3, 16, kernel_size=3, stride = 1, padding=1)
        self.relu = torch.nn.ReLU()
        self.pool = torch.nn.MaxPool2d(2, 2)  
        self.fc = torch.nn.Linear(16 * 16 * 16, 10)
        
    def forward(self, x):
        x.to(device)
        x = self.conv(x)
        x = self.relu(x)
        x = self.pool(x)
        x = x.flatten(1)     
        x = self.fc(x)
        return x
    
model = ConvNN()

# %%
optim = AdamW(model.parameters() ,lr = 0.052)
criterion = CrossEntropyLoss()

# %%
model.to(device)

for epoch in range(10):
    for X, Y in trainloader:
        
        X.to(device) 
        Y.to(device)
        print(type(X))
        
        optim.zero_grad()
        
        preds = model(X)   
        loss = criterion(preds, Y)
        
        loss.backward()
        optim.step()
# Out:
# <class 'torch.Tensor'>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[44], line 11
#       8 print(type(X))
#       9 optim.zero_grad()
# ---> 11 preds = model(X)
#      12 loss = criterion(preds, Y)
#      14 loss.backward()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
# ...
